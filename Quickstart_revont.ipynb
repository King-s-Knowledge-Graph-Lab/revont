# %%
#SETUP
#NOTE: Pleaset set to use GPU/TPU device in this colab kernel (On the above bar: Runtime -> Change runtime type)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !pwd
# Out:
# /content/drive/MyDrive

# %%
import os

if not os.path.exists('RevOnt'):
    # !git clone https://github.com/dignityc/RevOnt.git -b codeConsolidation
else:
    print("The 'RevOnt' already exists")
# !pip install -U sentence-transformers
# !pip install happytransformer
# !pip install qwikidata
# !pip install urllib3
# !pip install ijson
# !pip install simplejson
# !pip install urllib3==1.26.11
# !pip install -U git+https://github.com/amitness/colab-connect.git
# %cd RevOnt
# Out:
# The 'RevOnt' already exists
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 84.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 115.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.7 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=2f32b7c136abdbb3b688d11c8d4af27752441edcbd82a6cd0248140e1d7ca352
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 6.0 MB/s eta 0:00:00
# ...

# %%
from colabconnect import colabconnect

colabconnect()
# Out:
# Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Ran: ln -s /content/drive/MyDrive/colab/ /
# Installing python libraries...
# Ran: pip3 install --user flake8 black ipywidgets twine
# Ran: pip3 install -U ipykernel
# Ran: apt install htop -y
# Installing vscode-cli...
# Ran: curl -Lk https://code.visualstudio.com/sha/download?build=stable&os=cli-alpine-x64 --output vscode_cli.tar.gz
# Ran: tar -xf vscode_cli.tar.gz
# Starting the tunnel
# To grant access to the server, please log into https://github.com/login/device and use code 160B-BB45
# Starting the tunnel
# - Ready!
# - Open VSCode on your laptop and open the command prompt
# - Select: 'Remote-Tunnels: Connect to Tunnel' to connect to colab
# Logs:
#
# [2023-09-27 16:13:30] info [tunnels::connections::relay_tunnel_host] Opened new client on channel 2
# [2023-09-27 16:13:30] info [russh::server] wrote id
# ...

# %%
# !python main.py
# Out:
# 2023-09-25 12:27:37.117360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 09/25/2023 12:27:46 - INFO - happytransformer.happy_transformer -   Using device: cuda:0
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 32100. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# ...
